# %% [markdown]
# # <span style="color:darkblue"> QTM 151 - Quiz 2 </span>

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size="5">
#
# Print your name below

# %%
# Write your answer here

print("Mark Du")
# Out:
# Mark Du

# %% [markdown]
# <font size = "5" >
# This quiz is open book
#
# - You can use the lecture notes
# - You will get partial credit for attempting the questions
# - To get full credit, the code should run as intended
# - You should <span style="color:red"> NOT </span> communicate with other students
#
# Print the following message: <br>
#
# "I will abide by Emory's code of conduct"

# %%
# Write your answer here:
print("I will abide by Emory's code of conduct")
# Out:
# I will abide by Emory's code of conduct

# %% [markdown]
# <font size = "5">
#
# Import the libraries "numpy", "matplotlib.pyplot", and "pandas"

# %%
# Write your answer here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <font size = "5">
#
# Import the dataset "data_quiz/fifa23_players_basic.csv"
#
# - It's a dataset on professional soccer players
# - Rows correspond to players (18,539)
# - Columns contain attributes of players (32)
# - Try to view the dataset before starting

# %%
# Write your own code
fifa = pd.read_csv("data_quiz/fifa23_players_basic.csv")

# %% [markdown]
# <font size = "5">
#
# (a) Create a function and apply it to a column <br>
#
# <font size = "3">
#
# Step 1:
# - Define a function with a parameter "country"
# - If "country == United States", status = "US national"
# - Otherwise, status = "Not a US national"
# - The function returns "status"
#
# Step 2:
# - Extract the column "Nationality" in the dataset <br>
# (be carefeful to write the "N" (capitalized)
# - Create a new variable called "is_us_national" <br>
# to assign each player to the correct nationality status.
#
# HINT: Use the ".apply()" function

# %%
# Write your own code
def fn_nation(country):
    if(country == "United States"):
        status = "US national"
    else:
        status = "Not a US national"
    return(status)

fifa["is_us_national"] = fifa["Nationality"].apply(fn_nation)

# %% [markdown]
# <font size = "5">
#
# (b) Use queries + global variables
#
# <font size = "3">
#
# - Compute the median of the column "Value(in Euro)" <br>
# and store it as a variable
# - Subset the players whose value is above the median value <br>
#   using ".query()"
#
#
# HINT: Remember that there is a special syntax for <br>
# when the column names have spaces (see Lecture 10) <br>
# Reference the column as ``` `Wage(in Euro)`    ``` inside .query()

# %%
# Write your own code
median_value = fifa["Value(in Euro)"].median()
print(median_value)

fifa.query(" `Value(in Euro)` > @median_value")
# Out:
# 1000000.0
#              Known As              Full Name  Overall  Potential  \
# 0            L. Messi           Lionel Messi       91         91
# 1          K. Benzema          Karim Benzema       91         91
# 2      R. Lewandowski     Robert Lewandowski       91         91
# 3        K. De Bruyne        Kevin De Bruyne       91         91
# 4           K. Mbappé          Kylian Mbappé       91         95
# ...               ...                    ...      ...        ...
# 13696     S. Raebiger        Sidney Raebiger       62         84
# 13704      T. Bischof            Tom Bischof       62         83
# 13813            Simo  Wassim Keddari Boulif       62         83
# 13821    Z. Sertdemir        Zidan Sertdemir       62         83
# 13944        R. Lavia            Romeo Lavia       62         83
#
#        Value(in Euro) Positions Played Best Position Nationality  \
# 0            54000000               RW           CAM   Argentina
# 1            64000000            CF,ST            CF      France
# 2            84000000               ST            ST      Poland
# 3           107500000           CM,CAM            CM     Belgium
# 4           190500000            ST,LW            ST      France
# ...               ...              ...           ...         ...
# 13696         1200000           CM,CAM           CAM     Germany
# 13704         1200000              CAM           CAM     Germany
# 13813         1200000               CB            CB       Spain
# 13821         1200000           CM,CAM           CAM     Denmark
# 13944         1200000              CDM            CB     Belgium
#
#                                              Image Link  Age  ...  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png   35  ...
# 1      https://cdn.sofifa.net/players/165/153/23_60.png   34  ...
# 2      https://cdn.sofifa.net/players/188/545/23_60.png   33  ...
# 3      https://cdn.sofifa.net/players/192/985/23_60.png   31  ...
# 4      https://cdn.sofifa.net/players/231/747/23_60.png   23  ...
# ...                                                 ...  ...  ...
# 13696  https://cdn.sofifa.net/players/262/242/23_60.png   17  ...
# 13704  https://cdn.sofifa.net/players/263/765/23_60.png   17  ...
# 13813  https://cdn.sofifa.net/players/270/051/23_60.png   17  ...
# 13821  https://cdn.sofifa.net/players/263/312/23_60.png   17  ...
# 13944  https://cdn.sofifa.net/players/263/620/23_60.png   18  ...
#
#        Skill Moves  International Reputation  National Team Name  \
# 0                4                         5           Argentina
# 1                4                         4              France
# 2                4                         5              Poland
# 3                4                         4             Belgium
# 4                5                         4              France
# ...            ...                       ...                 ...
# 13696            3                         1                   -
# 13704            3                         1                   -
# 13813            2                         1                   -
# 13821            3                         1                   -
# 13944            2                         1                   -
#
#                   National Team Image Link National Team Position  \
# 0      https://cdn.sofifa.net/flags/ar.png                     RW
# 1      https://cdn.sofifa.net/flags/fr.png                     ST
# 2      https://cdn.sofifa.net/flags/pl.png                     ST
# 3      https://cdn.sofifa.net/flags/be.png                     RF
# 4      https://cdn.sofifa.net/flags/fr.png                     ST
# ...                                    ...                    ...
# 13696  https://cdn.sofifa.net/flags/de.png                      -
# 13704  https://cdn.sofifa.net/flags/de.png                      -
# 13813  https://cdn.sofifa.net/flags/es.png                      -
# 13821  https://cdn.sofifa.net/flags/dk.png                      -
# 13944  https://cdn.sofifa.net/flags/be.png                      -
#
#        National Team Jersey Number  Attacking Work Rate Defensive Work Rate  \
# 0                               10                  Low                 Low
# 1                               19               Medium              Medium
# 2                                9                 High              Medium
# 3                                7                 High                High
# 4                               10                 High                 Low
# ...                            ...                  ...                 ...
# 13696                            -               Medium              Medium
# 13704                            -               Medium              Medium
# 13813                            -                  Low              Medium
# 13821                            -               Medium              Medium
# 13944                            -               Medium                High
#
#           is_us_national status
# 0      Not a US national      0
# 1      Not a US national      1
# 2      Not a US national      1
# 3      Not a US national      0
# 4      Not a US national      0
# ...                  ...    ...
# 13696  Not a US national      0
# 13704  Not a US national      0
# 13813  Not a US national      1
# 13821  Not a US national      1
# 13944  Not a US national      0
#
# [8750 rows x 34 columns]

# %% [markdown]
# <font size = "5">
#
# (c) Use sorting + ".iloc[]"
#
# <font size = "3">
#
# - Use ".sort_values()" to order the "Potental" column <br>
# from highest to lowest
# - Get a subset with the 15 players with the highest potential

# %%
# Write your own code
fifa_potential = fifa.sort_values(by = "Potential", ascending = False)
display(fifa_potential.iloc[0:15,:])
# Out:
#           Known As                         Full Name  Overall  Potential  \
# 4        K. Mbappé                     Kylian Mbappé       91         95
# 21      E. Haaland                    Erling Haaland       88         94
# 82           Pedri              Pedro González López       85         93
# 83        P. Foden                        Phil Foden       85         92
# 63    Vinícius Jr.  Vinícius José de Oliveira Júnior       86         92
# 42      F. de Jong                   Frenkie de Jong       87         92
# 22   G. Donnarumma              Gianluigi Donnarumma       88         92
# 0         L. Messi                      Lionel Messi       91         91
# 16         Ederson         Ederson Santana de Moraes       89         91
# 1       K. Benzema                     Karim Benzema       91         91
# 152    D. Vlahović                    Dušan Vlahović       84         91
# 138     K. Havertz                       Kai Havertz       84         91
# 127       J. Tartt                       Jamie Tartt       84         91
# 124  J. Bellingham                   Jude Bellingham       84         91
# 20      Rúben Dias      Rúben Santos Gato Alves Dias       88         91
#
#      Value(in Euro) Positions Played Best Position  Nationality  \
# 4         190500000            ST,LW            ST       France
# 21        148000000               ST            ST       Norway
# 82        116000000               CM            CM        Spain
# 83        109500000        LW,CF,CAM           CAM      England
# 63        109000000               LW            LW       Brazil
# 42        116500000               CM            CM  Netherlands
# 22        103500000               GK            GK        Italy
# 0          54000000               RW           CAM    Argentina
# 16         88000000               GK            GK       Brazil
# 1          64000000            CF,ST            CF       France
# 152        86500000               ST            ST       Serbia
# 138        84500000        CAM,CF,ST           CAM      Germany
# 127        85500000               ST           CAM      England
# 124        81500000            CM,LM            CM      England
# 20        107500000               CB            CB     Portugal
#
#                                            Image Link  Age  ...  \
# 4    https://cdn.sofifa.net/players/231/747/23_60.png   23  ...
# 21   https://cdn.sofifa.net/players/239/085/23_60.png   21  ...
# 82   https://cdn.sofifa.net/players/251/854/23_60.png   19  ...
# 83   https://cdn.sofifa.net/players/237/692/23_60.png   22  ...
# 63   https://cdn.sofifa.net/players/238/794/23_60.png   21  ...
# 42   https://cdn.sofifa.net/players/228/702/23_60.png   25  ...
# 22   https://cdn.sofifa.net/players/230/621/23_60.png   23  ...
# 0    https://cdn.sofifa.net/players/158/023/23_60.png   35  ...
# 16   https://cdn.sofifa.net/players/210/257/23_60.png   28  ...
# 1    https://cdn.sofifa.net/players/165/153/23_60.png   34  ...
# 152  https://cdn.sofifa.net/players/246/430/23_60.png   22  ...
# 138  https://cdn.sofifa.net/players/235/790/23_60.png   23  ...
# 127  https://cdn.sofifa.net/players/269/761/23_60.png   24  ...
# 124  https://cdn.sofifa.net/players/252/371/23_60.png   19  ...
# 20   https://cdn.sofifa.net/players/239/818/23_60.png   25  ...
#
#      Weak Foot Rating  Skill Moves  International Reputation  \
# 4                   4            5                         4
# 21                  3            3                         4
# 82                  4            4                         2
# 83                  3            4                         3
# 63                  4            5                         2
# 42                  3            4                         3
# 22                  3            1                         3
# 0                   4            4                         5
# 16                  3            1                         3
# 1                   4            4                         4
# 152                 3            3                         2
# 138                 4            4                         3
# 127                 4            5                         1
# 124                 4            4                         2
# 20                  4            2                         3
#
#      National Team Name                 National Team Image Link  \
# 4                France      https://cdn.sofifa.net/flags/fr.png
# 21               Norway      https://cdn.sofifa.net/flags/no.png
# 82                Spain      https://cdn.sofifa.net/flags/es.png
# 83              England  https://cdn.sofifa.net/flags/gb-eng.png
# 63                    -      https://cdn.sofifa.net/flags/br.png
# 42          Netherlands      https://cdn.sofifa.net/flags/nl.png
# 22                Italy      https://cdn.sofifa.net/flags/it.png
# 0             Argentina      https://cdn.sofifa.net/flags/ar.png
# 16                    -      https://cdn.sofifa.net/flags/br.png
# 1                France      https://cdn.sofifa.net/flags/fr.png
# 152                   -                                        -
# 138             Germany      https://cdn.sofifa.net/flags/de.png
# 127                   -  https://cdn.sofifa.net/flags/gb-eng.png
# 124             England  https://cdn.sofifa.net/flags/gb-eng.png
# 20             Portugal      https://cdn.sofifa.net/flags/pt.png
#
#      National Team Position  National Team Jersey Number Attacking Work Rate  \
# 4                        ST                           10                High
# 21                       ST                            9                High
# 82                       CM                           10                High
# 83                       RW                           20                High
# 63                        -                            -                High
# 42                      CDM                           21                High
# 22                       GK                           21              Medium
# 0                        RW                           10                 Low
# 16                        -                            -              Medium
# 1                        ST                           19              Medium
# 152                       -                            -              Medium
# 138                     SUB                            7              Medium
# 127                       -                            -                High
# 124                     SUB                           26                High
# 20                       CB                            4              Medium
#
#     Defensive Work Rate     is_us_national
# 4                   Low  Not a US national
# 21               Medium  Not a US national
# 82                 High  Not a US national
# 83                 High  Not a US national
# 63               Medium  Not a US national
# 42               Medium  Not a US national
# 22               Medium  Not a US national
# 0                   Low  Not a US national
# 16               Medium  Not a US national
# 1                Medium  Not a US national
# 152              Medium  Not a US national
# 138              Medium  Not a US national
# 127                 Low  Not a US national
# 124                High  Not a US national
# 20                 High  Not a US national
#
# [15 rows x 33 columns]

# %% [markdown]
# <font size = "5">
#
# (d) Create a function with five inputs $f(y,x,b0,b1,b2)$
#
# <font size = "3">
#
# $\qquad e = y - b_0 - b_1 * x - b_2 * x^2 $ <br>
# $\qquad e2 = e^2$
#
# - The function should return the mean of e2
# - This is the mean-square error (mse)
# - Call the function "fn_mse"
# - Let $y$ be the column "Potential"
# - Let $x$ be the column "Age"
# - Does <br>
# $\qquad (b_0 = 90, b_1 = -1, b2 = -50)$ or <br>
# $\qquad (b_0 = 90, b_1 = -1, b2 = 0)$ or <br>
# $\qquad (b_0 = 90, b_1 = -1, b2 = 50)$ <br>
# produce the lowest value of mse?

# %%
# Write your own code
def fn_mse(y,x,b0,b1,b2):
    e= y-b0-b1*x-b2*x**2
    e2 = e**2
    return(e2.mean())

print(fn_mse(y=fifa["Potential"],x=fifa["Age"],b0=90,b1=-1,b2=-50))
print(fn_mse(y=fifa["Potential"],x=fifa["Age"],b0=90,b1=-1,b2=0))
print(fn_mse(y=fifa["Potential"],x=fifa["Age"],b0=90,b1=-1,b2=50))

#B is lowest
# Out:
# 1242530544.1125195
# 84.35201467177302
# 1241549938.5243

# %% [markdown]
# <font size = "5">
#
# (e) Split a dataset into subsets
#
# <font size = "3">
#
# - Create ``` list_status = [0,1]```
# - Create ``` list_prob = [0.5, 0.5]```
# - Create a new variable $n$ with the number of rows of the dataset
# - Use
# ```python
#     np.random.choice(list_status,
#                      size = n,
#                      p = list_prob)
# ```
# $\qquad$ to create a new column called "status" <br>
# $\qquad$ which randomly assigns each row to "0" with probability 50% <br>
# $\qquad$ and to 1 with probability 50%
# - Use .query() to subset all observations with status == 0.<br>
# store it in a new dataset called "data0"
# - Use .query() to subset all observations with status == 1.<br>
# store it in a new dataset called "data1"

# %%
# Write your own code
list_status = [0,1]
list_prob = [0.5, 0.5]
n = len(fifa)

fifa["status"] = np.random.choice(list_status, size = n, p =list_prob)

data0= fifa.query("status == 0")
data1= fifa.query("status == 1")

# %% [markdown]
# <font size = "5">
#
# (f) Create two overlapping histogram plots
#
# <font size = "3">
#
# - This function requires the two datasets you created in (e)
# - Display the distribution of "Overall" for "data0" and "data1"
# - Use the "alpha" option to make the graphs semitransparent
# - You will need to add a legend, label the axes, and the title
#
# Note: The goal of this question is to illustrate that random <br>
# assignment produces very similar distributions between two groups

# %%
# Write your own code



plt.hist(x = data0,alpha = 0.5)
plt.hist(x = data1,alpha = 0.5)
plt.xlabel("player")
plt.ylabel("frequency")
plt.legend(labels = ["0","1"],
           title  = "Overall Distribution")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/n1/cf4pjys55fngp3xffvpslsnw0000gn/T/ipykernel_79913/2965477605.py in <module>
#      10            title  = "Overall Distribution")
#      11
# ---> 12 plt.show()
#      13
#      14
#
# ~/opt/anaconda3/lib/python3.10/site-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     387     """
#     388     _warn_if_gui_out_of_main_thread()
# --> 389     return _get_backend_mod().show(*args, **kwargs)
#     390
#     391
#
# ~/opt/anaconda3/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      88     try:
#      89         for figure_manager in Gcf.get_all_fig_managers():
# ---> 90             display(
#      91                 figure_manager.canvas.figure,
#      92                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~/opt/anaconda3/lib/python3.10/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/opt/anaconda3/lib/python3.10/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# ~/opt/anaconda3/lib/python3.10/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.10/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/opt/anaconda3/lib/python3.10/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/opt/anaconda3/lib/python3.10/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# ~/opt/anaconda3/lib/python3.10/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2293                 )
#    2294                 with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2295                     self.figure.draw(renderer)
#    2296
#    2297             if bbox_inches:
#
# ~/opt/anaconda3/lib/python3.10/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      71     @wraps(draw)
#      72     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73         result = draw(artist, renderer, *args, **kwargs)
#      74         if renderer._rasterizing:
#      75             renderer.stop_rasterizing()
#
# ~/opt/anaconda3/lib/python3.10/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.10/site-packages/matplotlib/figure.py in draw(self, renderer)
#    2835
#    2836             self.patch.draw(renderer)
# -> 2837             mimage._draw_list_compositing_images(
#    2838                 renderer, self, artists, self.suppressComposite)
#    2839
#
# ~/opt/anaconda3/lib/python3.10/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/opt/anaconda3/lib/python3.10/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3089             renderer.stop_rasterizing()
#    3090
# -> 3091         mimage._draw_list_compositing_images(
#    3092             renderer, self, artists, self.figure.suppressComposite)
#    3093
#
# ~/opt/anaconda3/lib/python3.10/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/opt/anaconda3/lib/python3.10/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.10/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1168         # the actual bbox
#    1169
# -> 1170         self._update_label_position(renderer)
#    1171
#    1172         self.label.draw(renderer)
#
# ~/opt/anaconda3/lib/python3.10/site-packages/matplotlib/axis.py in _update_label_position(self, renderer)
#    2081         # get bounding boxes for this axis and any siblings
#    2082         # that have been set by `fig.align_xlabels()`
# -> 2083         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2084
#    2085         x, y = self.label.get_position()
#
# ~/opt/anaconda3/lib/python3.10/site-packages/matplotlib/axis.py in _get_tick_boxes_siblings(self, renderer)
#    1879             axis = getattr(ax, f"{axis_name}axis")
#    1880             ticks_to_draw = axis._update_ticks()
# -> 1881             tlb, tlb2 = axis._get_tick_bboxes(ticks_to_draw, renderer)
#    1882             bboxes.extend(tlb)
#    1883             bboxes2.extend(tlb2)
#
# ~/opt/anaconda3/lib/python3.10/site-packages/matplotlib/axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1083     def _get_tick_bboxes(self, ticks, renderer):
#    1084         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1085         return ([tick.label1.get_window_extent(renderer)
#    1086                  for tick in ticks if tick.label1.get_visible()],
#    1087                 [tick.label2.get_window_extent(renderer)
#
# ~/opt/anaconda3/lib/python3.10/site-packages/matplotlib/axis.py in <listcomp>(.0)
#    1083     def _get_tick_bboxes(self, ticks, renderer):
#    1084         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1085         return ([tick.label1.get_window_extent(renderer)
#    1086                  for tick in ticks if tick.label1.get_visible()],
#    1087                 [tick.label2.get_window_extent(renderer)
#
# ~/opt/anaconda3/lib/python3.10/site-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     908
#     909         with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 910             bbox, info, descent = self._get_layout(self._renderer)
#     911             x, y = self.get_unitless_position()
#     912             x, y = self.get_transform().transform((x, y))
#
# ~/opt/anaconda3/lib/python3.10/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     315             clean_line, ismath = self._preprocess_math(line)
#     316             if clean_line:
# --> 317                 w, h, d = renderer.get_text_width_height_descent(
#     318                     clean_line, self._fontproperties, ismath=ismath)
#     319             else:
#
# ~/opt/anaconda3/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     268         flags = get_hinting_flag()
#     269         font = self._get_agg_font(prop)
# --> 270         font.set_text(s, 0.0, flags=flags)
#     271         w, h = font.get_width_height()  # width and height of unrotated string
#     272         d = font.get_descent()
#
# KeyboardInterrupt:
